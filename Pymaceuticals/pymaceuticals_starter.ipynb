# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# Of the four high-performing regminens, it appears that Ramicane was the best performer. It had the lowest median tumor volume of 36.56mm3, while its next-nearest competitor, Capomulin, had a median tumor volume of 38.12mm3. Infubinol and Ceftamin performed particularly poorly with a median tumor volume of 60.17mm3, or about 1.6 times the median-size of tumor in a mouse treated with Ramicane.
#
# The efficacy of Capomulin on Mouse i557 seems to be largely limited to the first 5 to 7 days of treatment. There was a sharp decline in tumor volume during that period, after which the tumor seems to start a period of high growth.
#
# There is a strong, positive correlation between the weight of a mouse and the size of its tumor, as evidenced by the regression analysis displayed in the last figure.

# %% [markdown]
# ## Dependencies and starter code

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata = "data/Mouse_metadata.csv"
study_results = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata)
study_results = pd.read_csv(study_results)

# Combine the data into a single dataset
combined_df = pd.merge(mouse_metadata,study_results, on = "Mouse ID" )
combined_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %% [markdown]
# ## Summary statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Get volume for each Regimen
Ramicane_vol = combined_df.loc[combined_df["Drug Regimen"] == "Ramicane", "Tumor Volume (mm3)"]
Capomulin_vol = combined_df.loc[combined_df["Drug Regimen"] == "Capomulin", "Tumor Volume (mm3)"]
Infubinol_vol = combined_df.loc[combined_df["Drug Regimen"] == "Infubinol", "Tumor Volume (mm3)"]
Placebo_vol = combined_df.loc[combined_df["Drug Regimen"] == "Placebo", "Tumor Volume (mm3)"]
Ceftamin_vol = combined_df.loc[combined_df["Drug Regimen"] == "Ceftamin", "Tumor Volume (mm3)"]
Stelasyn_vol = combined_df.loc[combined_df["Drug Regimen"] == "Stelasyn", "Tumor Volume (mm3)"]
Zoniferol_vol = combined_df.loc[combined_df["Drug Regimen"] == "Zoniferol", "Tumor Volume (mm3)"]
Ketapril_vol = combined_df.loc[combined_df["Drug Regimen"] == "Ketapril", "Tumor Volume (mm3)"]
Propriva_vol = combined_df.loc[combined_df["Drug Regimen"] == "Propriva", "Tumor Volume (mm3)"]
Naftisol_vol = combined_df.loc[combined_df["Drug Regimen"] == "Naftisol", "Tumor Volume (mm3)"]


# Calculate mean for each regimen
Ramicane_mean =  np.mean(Ramicane_vol)
Capomulin_mean = np.mean(Capomulin_vol)
Infubinol_mean = np.mean(Infubinol_vol)
Placebo_mean =  np.mean(Placebo_vol)
Ceftamin_mean =  np.mean(Ceftamin_vol)
Stelasyn_mean = np.mean(Stelasyn_vol)
Zoniferol_mean = np.mean(Zoniferol_vol)
Ketapril_mean = np.mean(Ketapril_vol)
Propriva_mean = np.mean(Propriva_vol)
Naftisol_mean = np.mean(Naftisol_vol)


# Calculate median for each regimen
Ramicane_med =  np.median(Ramicane_vol)
Capomulin_med = np.median(Capomulin_vol)
Infubinol_med = np.median(Infubinol_vol)
Placebo_med =  np.median(Placebo_vol)
Ceftamin_med =  np.median(Ceftamin_vol)
Stelasyn_med = np.median(Stelasyn_vol)
Zoniferol_med = np.median(Zoniferol_vol)
Ketapril_med = np.median(Ketapril_vol)
Propriva_med = np.median(Propriva_vol)
Naftisol_med = np.median(Naftisol_vol)

# Calculate variance for each regimen
Ramicane_var =  np.var(Ramicane_vol)
Capomulin_var = np.var(Capomulin_vol)
Infubinol_var = np.var(Infubinol_vol)
Placebo_var =  np.var(Placebo_vol)
Ceftamin_var =  np.var(Ceftamin_vol)
Stelasyn_var = np.var(Stelasyn_vol)
Zoniferol_var = np.var(Zoniferol_vol)
Ketapril_var = np.var(Ketapril_vol)
Propriva_var = np.var(Propriva_vol)
Naftisol_var = np.var(Naftisol_vol)

# Calculate St Dev for each regimen
Ramicane_std =  np.std(Ramicane_vol)
Capomulin_std = np.std(Capomulin_vol)
Infubinol_std = np.std(Infubinol_vol)
Placebo_std =  np.std(Placebo_vol)
Ceftamin_std =  np.std(Ceftamin_vol)
Stelasyn_std = np.std(Stelasyn_vol)
Zoniferol_std = np.std(Zoniferol_vol)
Ketapril_std = np.std(Ketapril_vol)
Propriva_std = np.std(Propriva_vol)
Naftisol_std = np.std(Naftisol_vol)

# Calculate SEM for each regimen
Ramicane_sem =  st.sem(Ramicane_vol)
Capomulin_sem = st.sem(Capomulin_vol)
Infubinol_sem = st.sem(Infubinol_vol)
Placebo_sem =  st.sem(Placebo_vol)
Ceftamin_sem =  st.sem(Ceftamin_vol)
Stelasyn_sem = st.sem(Stelasyn_vol)
Zoniferol_sem = st.sem(Zoniferol_vol)
Ketapril_sem = st.sem(Ketapril_vol)
Propriva_sem = st.sem(Propriva_vol)
Naftisol_sem = st.sem(Naftisol_vol)


# Insert values into DataFrame
summary_df = pd.DataFrame({"Regimen": ["Ramicane", "Capomulin", "Infubinol","Placebo","Ceftamin","Stelasyn","Zoniferol"
                                       ,"Ketapril", "Propriva", "Naftisol"]
                           ,"Mean Tumor Vol": [Ramicane_mean 
                                                ,Capomulin_mean
                                                ,Infubinol_mean
                                                ,Placebo_mean
                                                ,Ceftamin_mean 
                                                ,Stelasyn_mean 
                                                ,Zoniferol_mean
                                                ,Ketapril_mean 
                                                ,Propriva_mean 
                                                ,Naftisol_mean]
                          ,"Tumor Variance": [Ramicane_var
                                            ,Capomulin_var
                                            ,Infubinol_var
                                            ,Placebo_var 
                                            ,Ceftamin_var
                                            ,Stelasyn_var
                                            ,Zoniferol_var
                                            ,Ketapril_var
                                            ,Propriva_var
                                            ,Naftisol_var]
                          
                           ,"Tumor Std. Dev.": [Ramicane_std
                                            ,Capomulin_std
                                            ,Infubinol_std
                                            ,Placebo_std 
                                            ,Ceftamin_std
                                            ,Stelasyn_std
                                            ,Zoniferol_std
                                            ,Ketapril_std
                                            ,Propriva_std
                                            ,Naftisol_std]
                          
                           ,"Tumor SEM": [Ramicane_sem
                                            ,Capomulin_sem
                                            ,Infubinol_sem
                                            ,Placebo_sem
                                            ,Ceftamin_sem
                                            ,Stelasyn_sem
                                            ,Zoniferol_sem
                                            ,Ketapril_sem
                                            ,Propriva_sem
                                            ,Naftisol_sem]})

summary_df
# Out:
#      Regimen  Mean Tumor Vol  Tumor Variance  Tumor Std. Dev.  Tumor SEM
# 0   Ramicane       40.216745       23.383692         4.835669   0.320955
# 1  Capomulin       40.675741       24.839296         4.983904   0.329346
# 2  Infubinol       52.884795       42.886388         6.548770   0.492236
# 3    Placebo       54.033581       60.830138         7.799368   0.581331
# 4   Ceftamin       52.591172       39.069446         6.250556   0.469821
# 5   Stelasyn       54.233149       59.122106         7.689090   0.573111
# 6  Zoniferol       53.236507       48.266689         6.947423   0.516398
# 7   Ketapril       55.235638       68.188930         8.257659   0.603860
# 8   Propriva       52.322552       42.088020         6.487528   0.512884
# 9   Naftisol       54.331565       65.817708         8.112811   0.596466

# %% [markdown]
# ## Bar plots

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pandas

# Create summary DF from value_counts for bar plot to reference
bar_plot_df = combined_df["Drug Regimen"].value_counts().rename_axis('Drug Regimen').reset_index(name='Counts')

sorted_bar_plot_df = bar_plot_df.sort_values(["Drug Regimen"])

# Create the plot
sorted_bar_plot_df.plot.bar(x = "Drug Regimen", y = "Counts", facecolor = "lightcoral"
                     , title = "Number of Data points per Regimen", figsize = (20,3), rot = 0
                    ,width = 0.75, legend = False)


plt.show()

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pyplot

# Create summary DF from value_counts for bar plot to reference
bar_plot_df = combined_df["Drug Regimen"].value_counts().rename_axis('Drug Regimen').reset_index(name='Counts')

sorted_bar_plot_df = bar_plot_df.sort_values(["Drug Regimen"])

# Set the x axis
x_axis = np.arange(len(sorted_bar_plot_df))
tick_locations = [value+0.4 for value in x_axis]

# Create the bar chart
plt.figure(figsize=(20,3))
plt.bar(x_axis, sorted_bar_plot_df["Counts"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, summary_df["Regimen"], rotation="horizontal")

# Set labels
plt.title("Number of Data points per Regimen")
# plt.xlabel("Regimen")
# plt.ylabel("Number of data points")

plt.show()

# %% [markdown]
# ## Pie plots

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# Create summary DF for pie plot to reference
pie_plot_df = combined_df["Sex"].value_counts().rename_axis('Sex').reset_index(name='Counts')

# Build the graph
colors = ["lightcoral", "lightskyblue"]
pie_plot_df.plot.pie(y = "Counts", title = "Mouse Gender", startangle=90, labels = pie_plot_df["Sex"]
                    ,autopct='%1.1f%%', colors = colors, legend = False, figsize = (4.5,4.5))

plt.axis("off")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# Create summary DF for pie plot to reference
pie_plot_df = combined_df["Sex"].value_counts().rename_axis('Sex').reset_index(name='Counts')

# Build pie plot
colors = ["lightcoral", "lightskyblue"]
plt.title("Mouse Gender")
plt.pie(pie_plot_df["Counts"], labels=pie_plot_df["Sex"], colors=colors,
        autopct="%1.1f%%", shadow=False, startangle=90)
plt.axis("equal")

plt.show()

# %% [markdown]
# ## Quartiles, outliers and boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the most promising treatment regimens. 

# Group the data on Mouse ID, Drug Regimen, and Tumor Vol
treatment_df = combined_df.loc[(combined_df["Drug Regimen"] == "Capomulin") 
                               | (combined_df["Drug Regimen"] == "Ramicane")
                               | (combined_df["Drug Regimen"] == "Infubinol") 
                               | (combined_df["Drug Regimen"] == "Ceftamin") 
                               ,["Mouse ID","Drug Regimen","Tumor Volume (mm3)"]]

grouped_treatment_df = treatment_df.groupby(["Drug Regimen", "Mouse ID"]).last()
sorted_treatment_df = grouped_treatment_df.sort_values(by = "Tumor Volume (mm3)").reset_index()
renamed_df = sorted_treatment_df.rename(columns = {"Tumor Volume (mm3)":"Final Tumor Volume"})
renamed_df
# Out:
#    Drug Regimen Mouse ID  Final Tumor Volume
# 0      Ramicane     k403           22.050126
# 1     Capomulin     s185           23.343598
# 2     Capomulin     m601           28.430964
# 3     Capomulin     x401           28.484033
# 4      Ramicane     g791           29.128472
# ..          ...      ...                 ...
# 95     Ceftamin     l471           67.748662
# 96    Infubinol     a203           67.973419
# 97     Ceftamin     y769           68.594745
# 98     Ceftamin     k210           68.923185
# 99    Infubinol     c139           72.226731
#
# [100 rows x 3 columns]

# %%
# Calculate the IQR and quantitatively determine if there are any potential outliers. 


# Insert final tumor volume to a var
final_tumor_vol_capomulin = renamed_df.loc[renamed_df["Drug Regimen"] == "Capomulin", "Final Tumor Volume"]
final_tumor_vol_ramicane = renamed_df.loc[renamed_df["Drug Regimen"] == "Ramicane","Final Tumor Volume"]
final_tumor_vol_infubinol = renamed_df.loc[renamed_df["Drug Regimen"] == "Infubinol","Final Tumor Volume"]
final_tumor_vol_ceftamin = renamed_df.loc[renamed_df["Drug Regimen"] == "Ceftamin","Final Tumor Volume"]


############################################
# Run statistics for Capomulin
############################################
# Calculate IQR Capomulin
quartiles_capomulin = final_tumor_vol_capomulin.quantile([.25, .5, .75])
lowerq_capomulin = quartiles_capomulin[0.25]
upperq_capomulin = quartiles_capomulin[0.75]
iqr_capomulin = upperq_capomulin - lowerq_capomulin


# Calculate upper and lower bounds
upper_bound_capomulin = upperq_capomulin + (1.5 * iqr_capomulin) # 94.04403868375002 data set has hi of 47.68596303
lower_bound_capomulin = lowerq_capomulin - (1.5 * iqr_capomulin) # 3.0739668737499812 data set has low of 23.34359787


# final_tumor_vol_capomulin
if final_tumor_vol_capomulin.max() > upper_bound_capomulin:
    print("There is an outlier above the upper bound in the Capomulin data set.")
elif final_tumor_vol_capomulin.min() < lower_bound_capomulin:
    print("There is an outlier below the lower bound in the Capomulin data set.")
elif final_tumor_vol_capomulin.max() > upper_bound_capomulin and final_tumor_vol_capomulin.min() < lower_bound_capomulin:
    print("There are outliers on the high and low side of the Capomulin set.")
else: 
    print("There are no outliers in the Capomulin data set!")
    
# ############################################
# # Run statistics for Ramicane
# ############################################
# # Calculate IQR Ramicane
quartiles_ramicane = final_tumor_vol_ramicane.quantile([.25, .5, .75])
lowerq_ramicane = quartiles_ramicane[0.25]
upperq_ramicane = quartiles_ramicane[0.75]
iqr_ramicane = upperq_ramicane - lowerq_ramicane

# Calculate upper and lower bounds
upper_bound_ramicane = upperq_ramicane + (1.5 * iqr_ramicane) #94.04403868375002
lower_bound_ramicane = lowerq_ramicane - (1.5 * iqr_ramicane) #3.0739668737499812


# final_tumor_vol_capomulin
if final_tumor_vol_ramicane.max() > upper_bound_ramicane:
    print("There is an outlier above the upper bound in the ramicane data set.")
elif final_tumor_vol_ramicane.min() < lower_bound_ramicane:
    print("There is an outlier below the lower bound in the ramicane data set.")
elif final_tumor_vol_ramicane.max() > upper_bound_ramicane and final_tumor_vol_ramicane.min() < lower_bound_ramicane:
    print("There are outliers on the high and low side of the Ramicane set.")
else: 
    print("There are no outliers in the ramicane data set!")
    

############################################
# Run statistics for Infubinol
############################################
# Calculate IQR infubinol
quartiles_infubinol = final_tumor_vol_infubinol.quantile([.25, .5, .75])
lowerq_infubinol = quartiles_infubinol[0.25]
upperq_infubinol = quartiles_infubinol[0.75]
iqr_infubinol = upperq_infubinol - lowerq_infubinol

# Calculate upper and lower bounds
upper_bound_infubinol = upperq_infubinol + (1.5 * iqr_infubinol) #
lower_bound_infubinol = lowerq_infubinol - (1.5 * iqr_infubinol) #


if final_tumor_vol_infubinol.max() > upper_bound_infubinol:
    print("There is an outlier above the upper bound in the infubinol data set.")
elif final_tumor_vol_infubinol.min() < lower_bound_infubinol:
    print("There is an outlier below the lower bound in the infubinol data set.")
elif final_tumor_vol_infubinol.max() > upper_bound_infubinol and final_tumor_vol_infubinol.min() < lower_bound_infubinol:
    print("There are outliers on the high and low side of the Infubinol set.")
else: 
    print("There are no outliers in the infubinol data set!")
    
    
############################################
# Run statistics for Ceftamin
############################################
# Calculate IQR ceftamin
quartiles_ceftamin = final_tumor_vol_ceftamin.quantile([.25, .5, .75])
lowerq_ceftamin = quartiles_ceftamin[0.25]
upperq_ceftamin = quartiles_ceftamin[0.75]
iqr_ceftamin = upperq_ceftamin - lowerq_ceftamin

# Calculate upper and lower bounds
upper_bound_ceftamin = upperq_ceftamin + (1.5 * iqr_ceftamin) #
lower_bound_ceftamin = lowerq_ceftamin - (1.5 * iqr_ceftamin) #


if final_tumor_vol_ceftamin.max() > upper_bound_ceftamin:
    print("There is an outlier above the upper bound in the ceftamin data set.")
elif final_tumor_vol_ceftamin.min() < lower_bound_ceftamin:
    print("There is an outlier below the lower bound in the ceftamin data set.")
elif final_tumor_vol_ceftamin.max() > upper_bound_ceftamin and final_tumor_vol_ceftamin.min() < lower_bound_ceftamin:
    print("There are outliers on the high and low side of the Ceftamin set.")
else: 
    print("There are no outliers in the ceftamin data set!")
    
# print(f"cap:{iqr_capomulin}, ram:{iqr_ramicane}, inf:{iqr_infubinol}, cef:{iqr_ceftamin}")
# print(f"cap:{quartiles_capomulin} ram: {quartiles_ramicane} inf{quartiles_infubinol} ceft: {quartiles_ceftamin}")
# Out:
# There are no outliers in the Capomulin data set!
# There are no outliers in the ramicane data set!
# There is an outlier below the lower bound in the infubinol data set.
# There are no outliers in the ceftamin data set!

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# Create four boxplots with tumor volume measurements.
# Boxes share y axis for easier comparison

red_square = dict(markerfacecolor='r', marker='s')
# Capomulin Box
fig1, (ax1, ax2, ax3, ax4) = plt.subplots(1,4, figsize=(20,7), sharey = True)
ax1.set_title('Capomulin', fontsize = 20)
ax1.set_ylabel('Tumor Volume (mm3)', fontsize = 15)
ax1.boxplot(final_tumor_vol_capomulin)

# Ramicane Box
ax2.set_title('Ramicane', fontsize = 20)
# ax2.set_ylabel('Tumor Volume (mm3)')
ax2.boxplot(final_tumor_vol_ramicane)

# Infubinol Box
ax3.set_title('Infubinol', fontsize = 20)
# ax2.set_ylabel('Tumor Volume (mm3)')
ax3.boxplot(final_tumor_vol_infubinol, flierprops=red_square)


# Ceftamin Box
ax4.set_title('Ceftamin', fontsize = 20)
# ax2.set_ylabel('Tumor Volume (mm3)')
ax4.boxplot(final_tumor_vol_ceftamin)
plt.show()

# %% [markdown]
# ## Line and scatter plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# Get capomulin mouse data
capo_mouse = combined_df.loc[combined_df["Drug Regimen"] == "Capomulin",["Mouse ID","Timepoint", "Tumor Volume (mm3)","Weight (g)"]]

# Pick a mouse
capo_mouse_gp = capo_mouse.loc[capo_mouse["Mouse ID"] == "i557", ["Mouse ID","Timepoint", "Tumor Volume (mm3)"]]

# capo_mouse_gp["Timepoint"]
xlim = 45
x_axis = capo_mouse_gp["Timepoint"]
y_axis = capo_mouse_gp["Tumor Volume (mm3)"]
plt.plot(x_axis, y_axis)


plt.title("Mouse i557 Tumor Size over Time")
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")


plt.ylim(42,50)

plt.show()

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# Group mouse data by Mouse ID and weight
capo_mouse_grouped = capo_mouse.groupby(["Mouse ID", "Weight (g)"])

# Calculate the mean for the group mice
capo_mouse_avg_vol= capo_mouse_grouped["Tumor Volume (mm3)"].mean()

# Create DF with new Mean data
capo_scatter_df = pd.DataFrame({"Avg_Tumor_Vol": capo_mouse_avg_vol
                               })
capo_scatter_df.reset_index(level=['Weight (g)'], inplace=True)

# Build the scatter plot
x_values = capo_scatter_df["Weight (g)"]
y_values = capo_scatter_df["Avg_Tumor_Vol"]

plt.scatter(x_values, y_values)
plt.xlabel("Mouse Weight")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()

# %%
# Calculate the correlation coefficient and linear regression model for mouse weight and average tumor 
# volume for the Capomulin regimen

# Set x and y values
x_values = capo_scatter_df["Weight (g)"]
y_values = capo_scatter_df["Avg_Tumor_Vol"]

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create Scatter plot
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")

# Style the plot
plt.annotate(line_eq,(20,36) ,fontsize = 12, color = "red")
plt.xlabel("Mouse Weight")
plt.ylabel("Average Tumor Size (mm3)")
plt.show()
